# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("question_1.csv")
df2=pd.read_csv("question_2.csv")

# %%
df1.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
df2.head()
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149

# %%
#import library to calculate the skewness
from scipy.stats import skew

df1['speed'].skew()
# Out:
# -0.11750986144663393

# %%
#import library to calculate the skewness
from scipy.stats import skew

df1['speed'].kurt()
# Out:
# -0.5089944204057617

# %%
plt.hist(df1['speed'])
# Out:
# (array([2., 3., 4., 6., 8., 5., 7., 8., 1., 6.]),
#  array([ 4. ,  6.1,  8.2, 10.3, 12.4, 14.5, 16.6, 18.7, 20.8, 22.9, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
# if the skewness is between -0.5 to 0.5 then we can say  it is nearly symmetrical 
#and therefore sdlightly skewed
# since -0.5089944204057617 is the value of the kurtosis therefore it is platykurtic
#as it is less than 3

# %% [markdown]
#  <h3> for distance Skewness<h3>
# <pre>Since skewness value is 0.80 and if skewness is between 0.5 and 1(positive skewed), the data are slightly skewed</pre>
#     <h3> for distance Kurtosis</h3>
#     <pre> since the value of kurtosis is 0.40 which is less than 3(kutosis<3) hence, it is platykuric</pre>

# %%
#import library to calculate the skewness
from scipy.stats import skew

df1['dist'].skew()
# Out:
# 0.8068949601674215

# %%
#import library to calculate the skewness
from scipy.stats import skew

df1['dist'].kurt()
# Out:
# 0.4050525816795765

# %%
plt.hist(df1['dist'])
# Out:
# (array([ 4.,  8., 14.,  6.,  7.,  4.,  3.,  3.,  0.,  1.]),
#  array([  2. ,  13.8,  25.6,  37.4,  49.2,  61. ,  72.8,  84.6,  96.4,
#         108.2, 120. ]),
#  <BarContainer object of 10 artists>)

# %%
#import library to calculate the skewness
from scipy.stats import skew

df2['SP'].skew()
# Out:
# 1.6114501961773586

# %%
from scipy.stats import skew

df2['SP'].kurt()
# Out:
# 2.9773289437871835

# %%
plt.hist(df2['SP'])
# Out:
# (array([ 8., 12., 32., 10., 10.,  2.,  1.,  2.,  1.,  3.]),
#  array([ 99.56490661, 106.56826723, 113.57162785, 120.57498847,
#         127.57834909, 134.58170971, 141.58507032, 148.58843094,
#         155.59179156, 162.59515218, 169.5985128 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
#  <pre><h1> for skewness</h1>
# since,skewness is greater than 1 (positive skewed), the data is extremely skewed
# <h1> for kurtosis</h1>
# since, kutosis is less than 3 it  means platykurtic</pre>

# %%
#import library to calculate the skewness
from scipy.stats import skew

df2['WT'].skew()
# Out:
# -0.6147533255357768

# %%
from scipy.stats import skew

df2['WT'].kurt()
# Out:
# 0.9502914910300326

# %%
plt.hist(df2['WT'])
# Out:
# (array([ 9.,  0.,  0., 22., 19., 18.,  7.,  5.,  0.,  1.]),
#  array([15.71285853, 19.44134791, 23.1698373 , 26.89832668, 30.62681606,
#         34.35530544, 38.08379483, 41.81228421, 45.54077359, 49.26926298,
#         52.99775236]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # <h4>Inference for WT</h4>
# <pre>Inference
# for Skewness
# Since, value of skewness is -0.603... it means this is negative skew because
# the value lie between -1 to -0.5 said to be negatively skewed
# for Kurtosis
# Since, value of kurtosis is 2.72... it means platykurtic (kurtosis<3) </pre>

# %% [markdown]
# # <h3>Q2) Draw inferences about the following boxplot & histogram</h3>
# <img src="histogram.png">
# <img src="histogram 2.png">

# %% [markdown]
#  <pre><h3> solution if 2<Q2) Draw inferences about the following boxplot & histogram/h3><pre>
# <pre>In histogram
# Skewness
# we found skewness is right skew
#
# In boxplot
# We found outliers and skewness is right skewed
# </pre>

# %% [markdown]
# <h1>ques 4</h1>
# <pre><h3>Below are the scores obtained by a student in tests
# 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56
# 1) Find mean, median, variance, standard deviation.
# 2) What can we say about the student marks</h3></pre>

# %%
arr=np.array([34,36,36,38,39,39,40,41,41,41,41,42,42,45,49,56])

# %%
#calculate mean
from statistics import mean
mean(arr)
# Out:
# 41

# %%
#calculate median
from statistics import median
median(arr)
# Out:
# 41.0

# %%
#calculate variance
from statistics import variance
variance(arr)
# Out:
# 28

# %%
#calculate the standard deviation
from statistics import stdev
stdev(arr)
# Out:
# 5.291502622129181

# %%
#calculate the mode
from statistics import mode
mode(arr)
# Out:
# 41

# %% [markdown]
# <h1>Inference</h1>
#  <pre>According to my analyzation average marks obtained by the class is 40 it means mostly student score 40 marks in exam . it means Knowledge od student in that subject is similar , it imply if we want to increase the marks of the student teacher need to change the strategy of teaching</pre>

# %% [markdown]
#  <h1>Question 5 what is the nature if the skewnesss when the mean, median and mode are equal</h1>

# %% [markdown]
#  <pre><code> when mean, meadian and mode are equal then it means nature of skewness is symmetric</code></pre>
# <img src="symmetrical.png">

# %% [markdown]
# #<h3>Q6) what is the nature of the skewness when mean>median</h3>

# %% [markdown]
#  <h3><pre> since mean>median it imply skewness is positively skewed</pre></h3>
# <img src="mean.png">

# %% [markdown]
# <pre>Q7) What is the nature of skewness when median > mean</pre>

# %% [markdown]
# <pre> since median>mean  so it is negatively skewed</pre>
# <img src="negative.png">

# %% [markdown]
# <pre>Q8) What does positive kurtosis value indicates for a data</pre>

# %% [markdown]
# <h3> Mostly positive value indicate Mesokutic and Leptokutic</h3>
# <pre>positive excess value of Kurtosis(>3) indicate that distribution is peaked
# and posses thick tails. LeptoKutic Distribution have positive Kurtosis values.
# A leptokutic distibution has a higher peak (thin bell) and taller tails than a normal.</pre>
# distribution</pre>
# <img src="lepto.jpg">

# %% [markdown]
#  <h3><pre>Q9) What does negative kurtosis value indicates for a data?</pre><h3>

# %% [markdown]
# <h3> Inference</h3>
# <pre> A distribution with a negative kurtosis value indicates that it is Platykutic and  the distribution has lighter tails than the normal distribution. For example, data that follow a beta distribution with first and second shape parameters equal to 2 have a negative kurtosis value.</pre>
# <img src="platykutic.png">

# %% [markdown]
# #<h3><pre>Q10) Answer the below questions using the below boxplot visualization</pre>
# <img src="boxplot.png">
# <pre>What can we say about the distribution of the
# data? What is nature of skewness of the data?
# What will be the IQR of the data (approximately)</pre>

# %% [markdown]
# <pre><br>the vertical line inside the box that represents the median is much closer to the third quartile than the first quartile, which means the distribution is left-skewed.
# =>The interquartile range, often abbreviated IQR, is the difference between the third quartile and the first quartile.
#
# IQR  = Q3 – Q1
# Q3 (Upper Quartile) = 18
# Q1 (Lower Quartile) = 10
# Interquartile Range (IQR) = 18 – 10 = 8
# </br></pre>
# <img src="boxplot.jpeg">

# %% [markdown]
#  <pre><h3>Q)11  Comment on the below Boxplot visualizations?</h3></pre>
# <img src="box.png">
# <pre><b>Draw an Inference from the distribution of data for Boxplot 1 with respect Boxplot 2.</b><pre>

# %% [markdown]
# <pre>Observation
# <b>Median Values Compare</b>
# The line in the middle of the box plot for  boxplot 1 is equal to the line for boxplot 2, which indicates that  boxplot1 and boxplot2 has same median.
# <b>Calculate dispersion</b>
# The box plot for boxplot 2 is much longer than Boxplot 1, which indicates that the data are much more spread out among boxplot1 who used boxplot 2.
# <b>Skewness compare</b>
# The line in the middle of the box plot for boxplot 1  is close to median, which indicates that the distribution of data who used boxplot1 is no skewed. Similiarly , the line in the middle of the box plot for Boxplot 2  , which means the distribution of data is no skew at all.
# <b>Check Outliers present</b>
# Neither box plot has tiny circles that extend beyond the top or bottom whiskers, which means neither dataset had any clear outliers.
# </pre>

# %% [markdown]
# #<pre><h3> Q)12Draw an Inference from the distribution of data for Boxplot 1 with respect Boxplot 2.</h3></pre>
# <img src="variable.png">
# <pre>Answer the following three questions based on the histogram above.
# (i) Where would the mode of this dataset lie?
# (ii) Comment on the skewness of the dataset.
# (iii) Suppose that the above histogram and the boxplot in question 2 are
# plotted for the same dataset. Explain how these graphs complement each
# other inproviding information about any dataset
# </pre>

# %% [markdown]
#  <pre>Mode for dataset
# =>It is multimodal dataset, therfore mode set is{5,7};
# Skewness for dataset
# =>It is found as right skew dataset
#
#
# =>Both provide information about right skew
#
# </pre>
