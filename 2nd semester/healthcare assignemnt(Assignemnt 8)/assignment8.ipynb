# %%
# analysis heathcare.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('healthcare.csv')
df.head()

df.info()

df.describe()

df.isnull().sum()


# In[ ]:


# Data Visualization
  
# 1. Plot the distribution of age, bmi, charges columns. 

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)

sns.distplot(df['age'],color='red')

plt.subplot(1,3,2)

sns.distplot(df['bmi'],color='green')

plt.subplot(1,3,3)

sns.distplot(df['charges'],color='blue')

plt.show()


# In[ ]:


    
# 2. Plot the countplot of 'smoker' and 'region' columns.

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)

sns.countplot(df['smoker'],palette='Set1')

plt.subplot(1,2,2)

sns.countplot(df['region'],palette='Set1')

plt.show()

 
# In[ ]:


# 3. Plot the pairplot of dataframe.

sns.pairplot(df)

plt.show()


# In[ ]:


# 4. Plot the heatmap of correlation matrix.

plt.figure(figsize=(10,5))

sns.heatmap(df.corr(),annot=True)

plt.show()


# In[ ]:


# 5. Plot the barplot of 'smoker' with 'charges' columns.

plt.figure(figsize=(10,5))

sns.barplot(x='smoker',y='charges',data=df)

plt.show()

    
# In[ ]:

 
# 6. Plot the barplot of 'region' with 'charges' columns.

plt.figure(figsize=(10,5))
 
sns.barplot(x='region',y='charges',data=df)

plt.show()

 
# In[ ]:

 
# 7. Plot the barplot of  'children' with 'charges' columns.

plt.figure(figsize=(10,5))

sns.barplot(x='children',y='charges',data=df)

plt.show()

 
# In[ ]:


# 8. Plot the barplot of 

plt.figure(figsize=(10,5))

sns.barplot

plt.show()

 
# In[ ]:


# 9. Plot the barplot of   with 'charges' columns.

plt.figure(figsize=(10,5))

sns.barplot

plt.show()


# In[ ]:

#  measure of cnetral tendency

# 1. Find the mean of 'charges' column.

df['charges'].mean()


# In[ ]:

  
# 2. Find the median of 'charges' column.

df['charges'].median()

 
# In[ ]:

    
# 3. Find the mode of 'charges' column.

df['charges'].mode()

 
 
# In[ ]:

  
# 4. Find the mean of 'bmi' column.

df['bmi'].mean()


# In[ ]:


# 5. Find the median of 'bmi' column.

df['bmi'].median()

    
# In[ ]:

 
# 6. Find the mode of 'bmi' column.

df['bmi'].mode()

    
# In[ ]:

    
# 7. Find the mean of 'age' column.

df['age'].mean()

 
# In[ ]:

     
# 8. Find the median of 'age' column.

df['age'].median()

  
# In[ ]:

 
# 9. Find the mode of 'age' column.

df['age'].mode()


# measure of dispersion

# 1. Find the range of 'charges' column.

df['charges'].max() - df['charges'].min()


# In[ ]:


# 2. Find the range of 'bmi' column.
 
df['bmi'].max() - df['bmi'].min()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   S. No.                                 16 non-null     int64
#  1   I.D No.                                16 non-null     object
#  2   Name                                   16 non-null     object
#  3   Age                                    16 non-null     int64
#  4   Gender                                 16 non-null     object
#  5   Height in meter                        16 non-null     float64
#  6   Height (feet)                          16 non-null     float64
#  7   Weight (kg)                            16 non-null     int64
#  8   BMI =  kg/m2                           16 non-null     float64
#  9   Distance in cm (prior-intervention)    16 non-null     float64
# ...
